# %%
import pandas as pd

# %%
df=pd.read_excel('nestle.xlsx','Only Data - Sales Analysis Dash',header=1)

# %%
df=df.drop(df.columns[0],axis=1)

# %%
df
# Out:
#        Sales ID       Date Product Name  Total Revenue  \
# 0      AT-18056 2020-06-07      Nescafe         279.30
# 1       AT-9867 2019-05-14      Nescafe         263.46
# 2      AT-11225 2019-07-07      Nescafe         258.72
# 3       AT-3208 2018-06-25      Nescafe         236.88
# 4      AT-18812 2020-07-04      Nescafe         235.20
# ...         ...        ...          ...            ...
# 18110  AT-15454 2020-01-10      Nescafe         257.25
# 18111  AT-16636 2020-03-28      Nescafe         220.50
# 18112  AT-16118 2020-02-26      Nescafe         171.50
# 18113  AT-19208 2020-07-18      Nescafe         130.46
# 18114  AT-20288 2020-08-27      Nescafe         130.46
#
#                      Sales Location Sales Medium  Sales count  Product Count
# 0      Australian Capital Territory       Online            1              1
# 1      Australian Capital Territory       Direct            1              1
# ...

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index(df.Date, inplace=True)

# %%
df
# Out:
#             Sales ID       Date Product Name  Total Revenue  \
# Date
# 2020-06-07  AT-18056 2020-06-07      Nescafe         279.30
# 2019-05-14   AT-9867 2019-05-14      Nescafe         263.46
# 2019-07-07  AT-11225 2019-07-07      Nescafe         258.72
# 2018-06-25   AT-3208 2018-06-25      Nescafe         236.88
# 2020-07-04  AT-18812 2020-07-04      Nescafe         235.20
# ...              ...        ...          ...            ...
# 2020-01-10  AT-15454 2020-01-10      Nescafe         257.25
# 2020-03-28  AT-16636 2020-03-28      Nescafe         220.50
# 2020-02-26  AT-16118 2020-02-26      Nescafe         171.50
# 2020-07-18  AT-19208 2020-07-18      Nescafe         130.46
# 2020-08-27  AT-20288 2020-08-27      Nescafe         130.46
#
#                           Sales Location Sales Medium  Sales count  \
# Date
# 2020-06-07  Australian Capital Territory       Online            1
# 2019-05-14  Australian Capital Territory       Direct            1
# ...

# %%
new_df=df.fillna(0)

# %%
new_df
# Out:
#             Sales ID       Date Product Name  Total Revenue  \
# Date
# 2020-06-07  AT-18056 2020-06-07      Nescafe         279.30
# 2019-05-14   AT-9867 2019-05-14      Nescafe         263.46
# 2019-07-07  AT-11225 2019-07-07      Nescafe         258.72
# 2018-06-25   AT-3208 2018-06-25      Nescafe         236.88
# 2020-07-04  AT-18812 2020-07-04      Nescafe         235.20
# ...              ...        ...          ...            ...
# 2020-01-10  AT-15454 2020-01-10      Nescafe         257.25
# 2020-03-28  AT-16636 2020-03-28      Nescafe         220.50
# 2020-02-26  AT-16118 2020-02-26      Nescafe         171.50
# 2020-07-18  AT-19208 2020-07-18      Nescafe         130.46
# 2020-08-27  AT-20288 2020-08-27      Nescafe         130.46
#
#                           Sales Location Sales Medium  Sales count  \
# Date
# 2020-06-07  Australian Capital Territory       Online            1
# 2019-05-14  Australian Capital Territory       Direct            1
# ...

# %%
us_weather=pd.DataFrame({
    "place":["seattle","washington","orlando"],
    "temperature":["cold","hot","humid"],
    "rating":[2,6,8]
})

# %%
ind_weather=pd.DataFrame({
    "place":["banaras","ghaziabad","noida"],
    "temperature":["cold","hot","hot"],
    "rating":[5,1,1]
})

# %%
d=pd.concat([us_weather,ind_weather],ignore_index=True)

# %%
import matplotlib.pyplot as plt
plt.plot(d.rating)

# %%
import numpy as np
x=np.arange(1,8,dtype=int).tolist()

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
y=[5,6,3,7,8,1,3]

# %%
plt.plot(x,y,'g+')

# %%
plt.plot(x,y,color='#000000',marker='D',markersize=10,alpha=0.1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,42,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,46,40,42,41,56]
